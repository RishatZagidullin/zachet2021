# %% [markdown]
# # Вариант 15

# %% [markdown]
# ## Задание 1
#
# программа просит ввести 2 числа и затем выводит модуль их разности

# %% [markdown]
# ## Задание 2
#
# программа которая находит сумму элеметнов числа
